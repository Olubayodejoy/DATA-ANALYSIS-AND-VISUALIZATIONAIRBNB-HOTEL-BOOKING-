# %%
import pandas as pd

# %%
hotel_booking_df = pd.read_csv('C:\\Users\\HP\\Documents\\hotel_booking.csv')
hotel_booking_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_booking2_df = pd.read_csv('C:\\Users\\HP\\Documents\\HotelBooking.csv')
hotel_booking2_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_booking_df.head(20)
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 0   Resort Hotel            0        342               2015
# 1   Resort Hotel            0        737               2015
# 2   Resort Hotel            0          7               2015
# 3   Resort Hotel            0         13               2015
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 6   Resort Hotel            0          0               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# ...

# %%
hotel_booking_df.shape
# Out:
# (119390, 36)

# %%
import os

# %%
col_change = pd.read_csv('C:\\Users\\HP\\Documents\\hotel_booking.csv', index_col = 'hotel')
col_change
# Out:
#               is_canceled  lead_time  arrival_date_year arrival_date_month  \
# hotel
# Resort Hotel            0        342               2015               July
# Resort Hotel            0        737               2015               July
# Resort Hotel            0          7               2015               July
# Resort Hotel            0         13               2015               July
# Resort Hotel            0         14               2015               July
# ...                   ...        ...                ...                ...
# City Hotel              0         23               2017             August
# City Hotel              0        102               2017             August
# City Hotel              0         34               2017             August
# City Hotel              0        109               2017             August
# City Hotel              0        205               2017             August
#
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
arrival_date = hotel_booking_df.arrival_date_month.value_counts().head(20)
arrival_date
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(x=arrival_date.index, y=arrival_date);

# %%
plt.figure(figsize=(12,6))
plt.title("MONTH")
plt.pie(arrival_date, labels=arrival_date.index, autopct='%1.2f%%', startangle=360);

# %%
edgraph = hotel_booking_df.arrival_date_year.value_counts()
edgraph
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
# ?sns.barplot

# %%
plt.figure(figsize=(20, 15))
sns.barplot(x=edgraph.values, y= edgraph.index )
# Out:
# <Axes: ylabel='arrival_date_year'>

# %%
sns.countplot(y=hotel_booking_df.arrival_date_month)
plt.xticks(rotation=75)
plt.title('Count of Bookings by Arrival Date')
plt.ylabel(None)
plt.show()

# %%
print(hotel_booking_df.columns)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
sns.scatterplot(x='arrival_date_week_number', y='arrival_date_day_of_month',hue='hotel', data=hotel_booking_df)
plt.xlabel("arrival_date_week")
plt.ylabel("arrival_date_day_of_month");
